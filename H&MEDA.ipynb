# %%
import pandas as pd

# %% [markdown]
# conda install dask

# %%
customers_path = 'customers.csv'
transactionsTrain_path = '/Users/jamester/Documents/MachineLearning/KaggleComps/H&M/transactions_train.csv'
articles_path = '/Users/jamester/Documents/MachineLearning/KaggleComps/H&M/articles.csv'

# %%
customers_df =  pd.read_csv(customers_path)
transactions_df = pd.read_csv(transactionsTrain_path)
articles_df = pd.read_csv(articles_path)

# %%
display(customers_df.head())
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# ...

# %%
display(customers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355971 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB
# None

# %%
customers_df.nunique()
# Out:
# customer_id               1371980
# FN                              1
# Active                          1
# club_member_status              3
# fashion_news_frequency          4
# age                            84
# postal_code                352899
# dtype: int64

# %%
transactions_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31788324 entries, 0 to 31788323
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   t_dat             object
#  1   customer_id       object
#  2   article_id        int64
#  3   price             float64
#  4   sales_channel_id  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.2+ GB

# %%
transactions_df.nunique()
# Out:
# t_dat                   734
# customer_id         1362281
# article_id           104547
# price                  9857
# sales_channel_id          2
# dtype: int64

# %%
articles_df.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# ...

# %%
articles_df['article_id'].nunique()
# Out:
# 105542

# %%
def num_unique(df, column):
    return df[column].nunique()

# %%
num_unique(articles_df, 'product_group_name')
# Out:
# 19

# %%
articles_df.product_group_name
# Out:
# 0         Garment Upper body
# 1         Garment Upper body
# 2         Garment Upper body
# 3                  Underwear
# 4                  Underwear
#                  ...
# 105537        Socks & Tights
# 105538    Garment Upper body
# 105539     Garment Full body
# 105540           Accessories
# 105541     Garment Full body
# Name: product_group_name, Length: 105542, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
def plot_hist(df, column):
    plt.hist(df[column])
    plt.show()

# %% [markdown]
# plot_hist(customers_df, 'age')

# %%
ageByMembership = customers_df.loc[customers_df['club_member_status']=='ACTIVE'].groupby('age')

# %% [markdown]
# customers_df['age'].hist(by=customers_df['club_member_status'])

# %% [markdown]
# # Merge customer and transactions data

# %% [markdown]
# custTrans = transactions_df.merge(customers_df, on='customer_id', how='left')

# %% [markdown]
# custTrans.info()

# %% [markdown]
# custTrans.to_csv('custTrans.csv', index=False)

# %% [markdown]
# custTrans = cutTrans.read_csv('custTrans.csv')

# %%
custTransartStr = pd.read_csv('custTransStr.csv')

# %%
custTransartStr['article_id'] = custTransartStr['article_id'].apply(str)

# %%
custTransartStr.info()

# %% [markdown]
# Data prep and getting apriori method ready

# %% [markdown]
# art_by_trans = pd.DataFrame(custTransartStr.groupby(['t_dat', 'customer_id'])['article_id'].apply(list))

# %%
art_by_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9080179 entries, ('2018-09-20', '000058a12d5b43e67d225668fa1f8d618c13dc232df0cad8ffe7ad4a1091e318') to ('2020-09-22', 'fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20e02ce5d1e58a8f700b')
# Data columns (total 1 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   article_id  object
# dtypes: object(1)
# memory usage: 171.7+ MB

# %%
trans_list = art_by_trans['article_id'].to_list()

# %%
trans_list
# Out:
# [['663713001', '541518023'],
#  ['505221004', '685687003', '685687004', '685687001', '505221001'],
#  ['688873012', '501323011', '598859003', '688873020', '688873011'],
#  ['531310002', '529841001'],
#  ['501820043',
#   '501820043',
#   '674681001',
#   '671505001',
#   '671505001',
#   '631848002',
#   '631848002',
#   '631848002',
#   '631848002',
#   '680187001',
#   '676827002',
#   '676827002',
#   '685687002',
#   '685687002',
#   '680912006',
#   '680912006',
#   '692454002',
#   '692454002',
#   '640639001',
#   '640639001',
#   '664421002',
#   '664421002',
#   '680912009',
#   '680912009',
#   '553139001',
#   '553139001',
#   '377277001',
#   '377277001',
#   '700819006',
#   '700819006'],
#  ['397068015'],
#  ['652075001', '670295001'],
#  ['631744002', '562252035'],
#  ['649356002', '579941002', '629760002', '625229004'],
#  ['688545001'],
#  ['673531001', '464277014', '464277014'],
#  ['617322003', '617322003', '620405001', '678239001'],
#  ['613456009',
# ...

# %%
art_by_trans.to_csv('art_by_trans.csv')

# %% [markdown]
# conda install pyspark

# %%
art_by_trans = pd.read_csv('art_by_trans.csv')

# %% [markdown]
# # Get Transaction totals

# %% [markdown]
# transTotals = pd.DataFrame(custTrans.groupby(['t_dat','customer_id']).price.sum())

# %% [markdown]
# transTotals.to_csv('transTotals.csv')

# %%
transTotals = pd.read_csv('transTotals.csv')

# %%
transTotals.head()
# Out:
#         t_dat                                        customer_id     price
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0.081322
# 1  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0.086356
# 2  2018-09-20  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...  0.190593
# 3  2018-09-20  0008968c0d451dbc5a9968da03196fe20051965edde741...  0.042847
# 4  2018-09-20  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...  0.713051

# %% [markdown]
# transTotalsCustInfo = transTotals.merge(custTrans, on='customer_id', how='left')

# %% [markdown]
# transTotalsCustInfo.to_csv('transTotalsCustInfo.csv')

# %% [markdown]
# transTotalsCustInfo = pd.read_csv('transTotalsCustInfo.csv')

# %% [markdown]
# Above Section on Google Colab

# %% [markdown]
# not on Colab yet

# %% [markdown]
# art_by_trans_split = pd.DataFrame(art_by_trans['article_id'].tolist())

# %% [markdown]
# #without_quotes = for i in art_by_trans_split[0].apply(str)
# without_quotes.head()
# #[[', '.join('"' + item + '"' for item in l)] for l in without_quotes]

# %% [markdown]
# !pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
my_transactionencoder = TransactionEncoder()

# fit the transaction encoder using the list of transaction tuples
my_transactionencoder.fit(trans_list)

# transform the list of transaction tuples into an array of encoded transactions
encoded_transactions = my_transactionencoder.transform(trans_list)

# convert the array of encoded transactions into a dataframe
encoded_transactions_df = pd.DataFrame(encoded_transactions, columns=my_transactionencoder.columns_)
encoded_transactions_df.head()
